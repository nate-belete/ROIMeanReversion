# %%
#Import required libraries
import yfinance as yf
import matplotlib.pyplot as plt
from MovingAverageCrossOver import MovingAverageCrossOver

#Define parameters
ticker = 'AAPL'
var = 'Close'
fast_sma = 5
slow_sma = 10
start_date = '2020-07-01'
end_date = '2020-12-31'
interval = '1d'

#Instantiate the class
mv = MovingAverageCrossOver(ticker, var, fast_sma, slow_sma, start_date, end_date, interval)

#Calculate the number of times the fast moving average crossed over the slow moving average
# crossovers = mv.calculate_crossovers()
# print("Number of crossovers: ", crossovers)

#Plot the moving average crossover
mv.plot_moving_average_crossover()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
